# %%
import matplotlib.pyplot as plt
import healpy as hp
import sys
sys.path.append('..')

# %%
# %load_ext autoreload
# %autoreload 2
from echolens import simulation

# %%
folder = '/Users/antoidicherianlonappan/Workspace/scratch'

# %%
model = ['d0','s0']

# %%
fg = simulation.Foregrounds(folder,1024,model)

# %%
fgmaps = fg.get_fg_TQU()
# Out:
# computing foregrounds: 100%|██████████| 20/20 [00:02<00:00,  8.71Freq/s]

# %%
hp.mollview(fgmaps[9][2],title='d0')
