# %%
import matplotlib.pyplot as plt
import healpy as hp
import sys
sys.path.append('..')

# %%
# %load_ext autoreload
# %autoreload 2
from echolens import simulation
# Out:
# INFO:echolens.mpi:mpi.py : setup OK
# [shadowfax.lan:88599] shmem: mmap: an error occurred while determining whether or not /var/folders/fk/bw41mft54xv7g50r77fysgwh0000gn/T//ompi.shadowfax.501/jf.0/2002386944/sm_segment.shadowfax.501.775a0000.0 could be created.

# %%
folder = '/Users/antoidicherianlonappan/Workspace/scratch'

# %%
model = ['d0','s0']

# %%
fg = simulation.Foregrounds(folder,1024,model)

# %%
fgmaps = fg.get_fg_alms()
# Out:
# computing foregrounds:   0%|          | 0/20 [00:00<?, ?Freq/s]
# PySM3 Sky is computed.
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# computing foregrounds: 100%|██████████| 20/20 [07:07<00:00, 21.38s/Freq]

# %%
hp.mollview(hp.alm2map(fgmaps[9],nside=512)[2],title='d0')
