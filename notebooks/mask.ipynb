# %%
import healpy as hp

# %%
# %load_ext autoreload
# %autoreload 2
from echolens import simulation

# %%
m = simulation.Mask(1024)

# %%
hp.mollview(m.get_mask(60), title='Mask',sub=(1,2,1))

# %%
hp.mollview(m.get_mask(80,apodize=True,apo_scale=2), title='Apo. Mask',sub=(1,2,1))
