# %%
import healpy as hp
from echolens import simulation

# %%
m = simulation.Mask()

# %%
hp.mollview(m.get_mask(60), title='Mask',sub=(1,2,1))

# %%
hp.mollview(m.apodize_mask(m.get_mask(60),scale=1), title='Mask',sub=(1,2,1))

# %%
hp.mollview(m.get_mask(80), title='Mask',sub=(1,2,1))
