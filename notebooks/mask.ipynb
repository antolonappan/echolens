# %%
import matplotlib.pyplot as plt
import healpy as hp
import sys
sys.path.append('..')

# %%
# %load_ext autoreload
# %autoreload 2
from echolens import simulation

# %%
m = simulation.Mask()

# %%
hp.mollview(m.get_mask(60), title='Mask')

# %%
hp.mollview(m.apodize_mask(m.get_mask(60),scale=1), title='Mask')
